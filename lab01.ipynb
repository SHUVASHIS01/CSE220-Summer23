# %%
import numpy as np
list1=[1, 2, 3, 4]
arr=np.array(list1)
print(arr)
print(type(arr))
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>

# %%
import numpy as np
tple= (1, 2, 3)
arr=np.array(tple)
print(arr)
print(type(arr))
# Out:
# [1 2 3]
# <class 'numpy.ndarray'>

# %%
l=np.zeros((5), dtype='i') #i= integer f=float
print(l)
# Out:
# [0 0 0 0 0]

# %%
l=np.zeros(5)
print(l)
# Out:
# [0. 0. 0. 0. 0.]

# %%
# task1
import numpy as np
def playRight(sequence, beats):
  for i in beats:
    if i==1:
      c=sequence[len(sequence)-1]
      for j in range (len(sequence)-1,0,-1):
        sequence[j]=sequence[j-1]
      sequence[0]=c
  return sequence


print("///  Test 01: Play Right  ///")
sequence=np.array([10,20,30,40,50,60])
beats = np.array([1,0,0,1,0,1])
returned_value = playRight(sequence, beats) 
print(f'Task 1: {returned_value}') # This should print [40, 50, 60, 10, 20, 30]
# unittest.output_test(returned_value, np.array([40, 50, 60, 10, 20, 30]))
# Out:
# ///  Test 01: Play Right  ///
# Task 1: [40 50 60 10 20 30]

# %%
#Task02
import numpy as np
def discardCards (cards, n):
  for i in range (0, len(cards)):
    if cards[i]==n:
      cards[i]=cards[i+1]
      



print("///  Test 02: Discard Cards  ///")
cards = np.array([1,2,3,2,8,2,2,5,7])
returned_value = discardCards(cards, 2)
print(f'Task 2: {returned_value}') # This should print [1, 3, 8, 5, 7, None, None, None, None]
# unittest.output_test(returned_value, [1, 3, 8, 5, 7, None, None, None, None])
# Out:
# ///  Test 02: Discard Cards  ///
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-d1ba2e12e9fd> in <cell line: 25>()
#      23 print("///  Test 02: Discard Cards  ///")
#      24 cards = np.array([1,2,3,2,8,2,2,5,7])
# ---> 25 returned_value = discardCards(cards, 2)
#      26 print(f'Task 2: {returned_value}') # This should print [1, 3, 8, 5, 7, None, None, None, None]
#      27 # unittest.output_test(returned_value, [1, 3, 8, 5, 7, None, None, None, None])
#
# <ipython-input-13-d1ba2e12e9fd> in discardCards(cards, number)
#      15         if cards[index] == number:
#      16             # Replace the card with None
# ---> 17             cards[index] = None
#      18
#      19         # Increment the index
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
