# %%
class Node:
  def __init__ (self,e,n):
    self.elem=e
    self.next=n
def createlist (a):
  head=Node(a[0], None)
  tail=head
  print(tail)
  for i in range (1, len(a)):
    n=Node(a[i],None)
    tail.next=n
    print(tail.next)
    tail=tail.next
  return head
a=[1,2,3,4,5,6,7,8,9]
print(createlist(a))
